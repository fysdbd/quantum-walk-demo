# %%
import sys, os
sys.path.append(os.path.join(os.getcwd(), os.path.pardir))

# %%
from quantumwalk import states, walkers

# %%
walker = walkers.OneDimensionalWalker(100)
walker.finish()
distribution = walker.get_probability_distribution()

# %%
import matplotlib.pyplot as plt
plt.plot(distribution[0], distribution[1])
plt.xlabel('Coordicate')
plt.ylabel('Probability')
plt.title('Probability Distribution of Quantum Random Walker')
plt.show()
